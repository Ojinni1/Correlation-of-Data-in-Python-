# %% [markdown]
# # Data Correlation in python

# %% [markdown]
# In this Project, i import a dataset(movies.csv) using read_csv into the jupyter notebook, cleansed it by adjusting the Dates, dropping of Nan values and dropping duplicates. before working on the data correlation.

# %%
#importing our library for the project

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None # size of the plot to be use

# %%
# importing the data(movies.csv dataset) to be use and also assigning a variable to it 

movies = pd.read_csv(r'/Users/gokeojinni/Downloads/movies.csv')

movies     # previewing the data
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# checking for how many  NaN value in the data
movies.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
'''to drop all NaN values in our datframe because we can't replace a budget with 0 nor the gross itll skew our 
result the best is to drop it '''

movies = movies.dropna(how= 'any', axis = 0)

# %%
# checking our dataframe if we successfully drop the NaN values 
movies.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
# checking for the data types we're having in the dataframe

movies.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#working with budget and gross columns as float might be a little bit inconvenience needs to change it to an int
movies['budget'] = movies['budget'].astype(int)
movies['gross'] = movies['gross'].astype(int)
movies
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
#the released date and the year doesn't match at some point so had to use the released date as the actual date 

movies['yearcorrect'] = movies['released'].str.extract(pat = '([0-9]{4})').astype(int)

movies = movies.drop('year', axis = 1)

# %%
movies.head(3)
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
#
#        gross            company  runtime  yearcorrect
# 0   46998772       Warner Bros.    146.0         1980
# ...

# %%
movies = movies.sort_values(by=['gross'], inplace = False, ascending=False)

# %%
#in case of any duplicates, it needs to to drop 

movies = movies.drop_duplicates()

# %%
movies.head(5)
# Out:
#                                             name rating   genre  \
# 5445                                      Avatar  PG-13  Action
# 7445                           Avengers: Endgame  PG-13  Action
# 3045                                     Titanic  PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action
# 7244                      Avengers: Infinity War  PG-13  Action
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# using scatter plot 

plt.scatter(x=movies['budget'], y=movies['gross'])
plt.title('Budget vs. Gross Earning')
plt.xlabel('Budget for film')
plt.ylabel('Gross Earning')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
movies.head(3)
# Out:
#                    name rating   genre                           released  \
# 5445             Avatar  PG-13  Action  December 18, 2009 (United States)
# 7445  Avengers: Endgame  PG-13  Action     April 26, 2019 (United States)
# 3045            Titanic  PG-13   Drama  December 19, 1997 (United States)
#
#       score      votes       director              writer               star  \
# 5445    7.8  1100000.0  James Cameron       James Cameron    Sam Worthington
# 7445    8.4   903000.0  Anthony Russo  Christopher Markus  Robert Downey Jr.
# 3045    7.8  1100000.0  James Cameron       James Cameron  Leonardo DiCaprio
#
#             country     budget       gross                company  runtime  \
# 5445  United States  237000000  2847246203  Twentieth Century Fox    162.0
# 7445  United States  356000000  2797501328         Marvel Studios    181.0
# 3045  United States  200000000  2201647264  Twentieth Century Fox    194.0
#
#       yearcorrect
# 5445         2009
# ...

# %%
# using seaborn to check for the correlation 

sns.regplot(x='budget', y= 'gross', data= movies, scatter_kws={'color' : 'red'}, line_kws={'color': 'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#looking at the correlation

# %% [markdown]
# Correlation is a statistical techniques which helps inn analyziong the relationship between two or more variables

# %%
movies.corr(method = 'pearson') other methods that can be used #kendall, spearman
# Out:
#                 score     votes    budget     gross   runtime  yearcorrect
# score        1.000000  0.474256  0.072001  0.222556  0.414068     0.061923
# votes        0.474256  1.000000  0.439675  0.614751  0.352303     0.203098
# budget       0.072001  0.439675  1.000000  0.740247  0.318695     0.320312
# gross        0.222556  0.614751  0.740247  1.000000  0.275796     0.268721
# runtime      0.414068  0.352303  0.318695  0.275796  1.000000     0.075294
# yearcorrect  0.061923  0.203098  0.320312  0.268721  0.075294     1.000000

# %%
correlation_matrix = movies.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movies Features')

plt.ylabel('Movies Features')

plt.show()

# %%
#checking for companies
movies.head()
# Out:
#                                             name rating   genre  \
# 5445                                      Avatar  PG-13  Action
# 7445                           Avengers: Endgame  PG-13  Action
# 3045                                     Titanic  PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action
# 7244                      Avengers: Infinity War  PG-13  Action
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %% [markdown]
# converting the columns with strings

# %%
movies_numerized = movies.copy()

for col_name in movies_numerized.columns:
    if(movies_numerized[col_name].dtype == 'object'):
        movies_numerized[col_name] = movies_numerized[col_name].astype('category')
        movies_numerized[col_name] = movies_numerized[col_name].cat.codes # it'll give it a random numerization 

movies_numerized
# Out:
#       name  rating  genre  released  score      votes  director  writer  star  \
# 5445   386       5      0       527    7.8  1100000.0       785    1263  1534
# 7445   388       5      0       137    8.4   903000.0       105     513  1470
# 3045  4909       5      6       534    7.8  1100000.0       785    1263  1073
# 6663  3643       5      0       529    7.8   876000.0       768    1806   356
# 7244   389       5      0       145    8.4   897000.0       105     513  1470
# ...    ...     ...    ...       ...    ...        ...       ...     ...   ...
# 5640  3794       6      6       890    5.8     3500.0       585    2924  1498
# 2434  2969       5      0      1467    4.5     1900.0      1805    3102   186
# 3681  1595       3      6      1721    6.8    43000.0       952    1683   527
# 272   2909       6      9      1525    3.9     2300.0       261      55  1473
# 3203  4966       5      4      2152    5.7     5800.0       651     161  1811
#
# ...

# %% [markdown]
# Correleation for every field in the movies dataset

# %%
correlation_matrix = movies_numerized.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movies Features')

plt.ylabel('Movies Features')

plt.show()

# %%
movies_numerized.corr()
# Out:
#                  name    rating     genre  released     score     votes  \
# name         1.000000 -0.029234  0.010996 -0.006152  0.014450  0.012615
# rating      -0.029234  1.000000  0.147796  0.018083  0.065983  0.006031
# genre        0.010996  0.147796  1.000000  0.022142  0.035106 -0.135990
# released    -0.006152  0.018083  0.022142  1.000000  0.045874  0.028833
# score        0.014450  0.065983  0.035106  0.045874  1.000000  0.474256
# votes        0.012615  0.006031 -0.135990  0.028833  0.474256  1.000000
# director     0.015246  0.014656 -0.008553  0.002308  0.005413 -0.010376
# writer       0.012880 -0.003149  0.017578  0.008072  0.012843 -0.005316
# star        -0.006882  0.009196  0.003341  0.015706  0.007296 -0.017638
# country     -0.025490  0.008230 -0.009164 -0.017228 -0.043051  0.041551
# budget       0.023392 -0.203946 -0.368523  0.019952  0.072001  0.439675
# gross        0.005639 -0.181906 -0.244101  0.008501  0.222556  0.614751
# ...

# %%
correlation_mat = movies_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              released      -0.006152
#              score          0.014450
#                               ...
# yearcorrect  budget         0.320312
#              gross          0.268721
#              company       -0.018806
#              runtime        0.075294
#              yearcorrect    1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# budget       genre         -0.368523
# genre        budget        -0.368523
#              gross         -0.244101
# gross        genre         -0.244101
# rating       budget        -0.203946
#                               ...
# released     released       1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 225, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs)> 0.5]

high_corr
# Out:
# votes        gross          0.614751
# gross        votes          0.614751
# budget       gross          0.740247
# gross        budget         0.740247
# name         name           1.000000
# writer       writer         1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
'''votes and budget has the highest correlation 

company has a low correlation '''
